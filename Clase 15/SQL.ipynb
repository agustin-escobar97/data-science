# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
pd.options.display.max_rows = 10

# %%
engine = create_engine('sqlite:///firstDB.db', echo=True)
df = pd.read_csv('C:/Users/Duskrieg/Documents/Coder House/Clase 15/customer.csv').to_sql('customer', engine, if_exists='replace', index=False)
df = pd.read_csv('C:/Users/Duskrieg/Documents/Coder House/Clase 15/call.csv').to_sql('call', engine, if_exists='replace', index=False)
df = pd.read_csv('C:/Users/Duskrieg/Documents/Coder House/Clase 15/agent.csv').to_sql('agent', engine, if_exists='replace', index=False)

def runQuery(sql):
    result = engine.connect().execute((text(sql)))
    return pd.DataFrame(result.fetchall(), columns=result.keys())
# Out:
# 2022-03-10 22:07:14,406 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("customer")
# 2022-03-10 22:07:14,407 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-03-10 22:07:14,408 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("customer")
# 2022-03-10 22:07:14,408 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-03-10 22:07:14,409 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-03-10 22:07:14,409 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-03-10 22:07:14,409 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("customer")
# 2022-03-10 22:07:14,410 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-03-10 22:07:14,411 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-03-10 22:07:14,411 INFO sqlalchemy.engine.Engine [raw sql] ('customer',)
# ...
